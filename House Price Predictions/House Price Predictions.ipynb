# %%
import pandas as pd

# %%
data = pd.read_csv("houseprice.csv", usecols=["SalePrice", "MSSubClass", "MSZoning", "LotFrontage", "LotArea", "Street", "YearBuilt", "LotShape", "1stFlrSF", "2ndFlrSF"]).dropna()

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  YearBuilt  \
# 0          60       RL         65.0     8450   Pave      Reg       2003
# 1          20       RL         80.0     9600   Pave      Reg       1976
# 2          60       RL         68.0    11250   Pave      IR1       2001
# 3          70       RL         60.0     9550   Pave      IR1       1915
# 4          60       RL         84.0    14260   Pave      IR1       2000
#
#    1stFlrSF  2ndFlrSF  SalePrice
# 0       856       854     208500
# 1      1262         0     181500
# 2       920       866     223500
# 3       961       756     140000
# 4      1145      1053     250000

# %%
data.shape
# Out:
# (1201, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1459
# Data columns (total 10 columns):
# MSSubClass     1201 non-null int64
# MSZoning       1201 non-null object
# LotFrontage    1201 non-null float64
# LotArea        1201 non-null int64
# Street         1201 non-null object
# LotShape       1201 non-null object
# YearBuilt      1201 non-null int64
# 1stFlrSF       1201 non-null int64
# 2ndFlrSF       1201 non-null int64
# SalePrice      1201 non-null int64
# dtypes: float64(1), int64(6), object(3)
# memory usage: 103.2+ KB

# %%
## print the lenght of the funique value 
for i in data.columns:
    print("Column name {} and unique values are {}".format(i,len(data[i].unique())))
# Out:
# Column name MSSubClass and unique values are 15
# Column name MSZoning and unique values are 5
# Column name LotFrontage and unique values are 110
# Column name LotArea and unique values are 869
# Column name Street and unique values are 2
# Column name LotShape and unique values are 4
# Column name YearBuilt and unique values are 112
# Column name 1stFlrSF and unique values are 678
# Column name 2ndFlrSF and unique values are 368
# Column name SalePrice and unique values are 597

# %%
import datetime 
datetime.datetime.now().year
# Out:
# 2020

# %%
data["Total Years"] = datetime.datetime.now().year - data["YearBuilt"]

# %%
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street LotShape  YearBuilt  \
# 0          60       RL         65.0     8450   Pave      Reg       2003
# 1          20       RL         80.0     9600   Pave      Reg       1976
# 2          60       RL         68.0    11250   Pave      IR1       2001
# 3          70       RL         60.0     9550   Pave      IR1       1915
# 4          60       RL         84.0    14260   Pave      IR1       2000
#
#    1stFlrSF  2ndFlrSF  SalePrice  Total Years
# 0       856       854     208500           17
# 1      1262         0     181500           44
# 2       920       866     223500           19
# 3       961       756     140000          105
# 4      1145      1053     250000           20

# %%
## drop the year built shape 
data.drop("YearBuilt", axis=1, inplace=True)

# %%
## create categorical features
cat_features=["MSSubClass", "MSZoning", "Street", "LotShape"]
out_feature="SalePrice"

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoders={}
for feature in cat_features:
    lbl_encoders[feature]=LabelEncoder()
    data[feature]=lbl_encoders[feature].fit_transform(data[feature])

# %%
data.head()
# Out:
#    MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  1stFlrSF  \
# 0           5         3         65.0     8450       1         3       856
# 1           0         3         80.0     9600       1         3      1262
# 2           5         3         68.0    11250       1         0       920
# 3           6         3         60.0     9550       1         0       961
# 4           5         3         84.0    14260       1         0      1145
#
#    2ndFlrSF  SalePrice  Total Years
# 0       854     208500           17
# 1         0     181500           44
# 2       866     223500           19
# 3       756     140000          105
# 4      1053     250000           20

# %%
## Stacking and Converting Into Tensors
import numpy as np 
cat_features=np.stack([data['MSSubClass'],data['MSZoning'],data['Street'],data['LotShape']],1)
cat_features
# Out:
# array([[5, 3, 1, 3],
#        [0, 3, 1, 3],
#        [5, 3, 1, 0],
#        ...,
#        [6, 3, 1, 3],
#        [0, 3, 1, 3],
#        [0, 3, 1, 3]], dtype=int64)

# %%
## Convert numpy to Tensors
import torch
cat_features=torch.tensor(cat_features,dtype=torch.int64)
cat_features
# Out:
# tensor([[5, 3, 1, 3],
#         [0, 3, 1, 3],
#         [5, 3, 1, 0],
#         ...,
#         [6, 3, 1, 3],
#         [0, 3, 1, 3],
#         [0, 3, 1, 3]])

# %%
## create continuous variable
cont_features=[]
for i in data.columns:
    if i in ["MSSubClass", "MSZoning", "Street", "LotShape","SalePrice"]:
        pass
    else:
        cont_features.append(i)

# %%
cont_features
# Out:
# ['LotFrontage', 'LotArea', '1stFlrSF', '2ndFlrSF', 'Total Years']

# %%
## Stacking continuous variable to a tensor
cont_values=np.stack([data[i].values for i in cont_features],axis=1)
cont_values=torch.tensor(cont_values,dtype=torch.float)
cont_values
# Out:
# tensor([[   65.,  8450.,   856.,   854.,    17.],
#         [   80.,  9600.,  1262.,     0.,    44.],
#         [   68., 11250.,   920.,   866.,    19.],
#         ...,
#         [   66.,  9042.,  1188.,  1152.,    79.],
#         [   68.,  9717.,  1078.,     0.,    70.],
#         [   75.,  9937.,  1256.,     0.,    55.]])

# %%
cont_values.dtype
# Out:
# torch.float32

# %%
## Dependent Feature 
y=torch.tensor(data['SalePrice'].values,dtype=torch.float).reshape(-1,1)
y
# Out:
# tensor([[208500.],
#         [181500.],
#         [223500.],
#         ...,
#         [266500.],
#         [142125.],
#         [147500.]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1201 entries, 0 to 1459
# Data columns (total 10 columns):
# MSSubClass     1201 non-null int64
# MSZoning       1201 non-null int32
# LotFrontage    1201 non-null float64
# LotArea        1201 non-null int64
# Street         1201 non-null int32
# LotShape       1201 non-null int32
# 1stFlrSF       1201 non-null int64
# 2ndFlrSF       1201 non-null int64
# SalePrice      1201 non-null int64
# Total Years    1201 non-null int64
# dtypes: float64(1), int32(3), int64(6)
# memory usage: 89.1 KB

# %%
data.shape
# Out:
# (1201, 10)

# %%
cat_features.shape, cont_values.shape, y.shape
# Out:
# (torch.Size([1201, 4]), torch.Size([1201, 5]), torch.Size([1201, 1]))

# %%
## Embedding size for categorical columns
cat_dims=[len(data[col].unique()) for col in ["MSSubClass", "MSZoning", "Street", "LotShape"]]

# %%
cat_dims
# Out:
# [15, 5, 2, 4]

# %%
embedding_dim= [(x, min(50, (x + 1) // 2)) for x in cat_dims]

# %%
## preprocessing step
embedding_dim
# Out:
# [(15, 8), (5, 3), (2, 1), (4, 2)]

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
embed_representation=nn.ModuleList([nn.Embedding(inp,out) for inp,out in embedding_dim])
embed_representation
# Out:
# ModuleList(
#   (0): Embedding(15, 8)
#   (1): Embedding(5, 3)
#   (2): Embedding(2, 1)
#   (3): Embedding(4, 2)
# )

# %%
cat_features
# Out:
# tensor([[5, 3, 1, 3],
#         [0, 3, 1, 3],
#         [5, 3, 1, 0],
#         ...,
#         [6, 3, 1, 3],
#         [0, 3, 1, 3],
#         [0, 3, 1, 3]])

# %%
cat_featuresz=cat_features[:4]
cat_featuresz
# Out:
# tensor([[5, 3, 1, 3],
#         [0, 3, 1, 3],
#         [5, 3, 1, 0],
#         [6, 3, 1, 0]])

# %%
pd.set_option('display.max_rows', 500)
embedding_val=[]
for i,e in enumerate(embed_representation):
    embedding_val.append(e(cat_features[:,i]))

# %%
embedding_val
# Out:
# [tensor([[-0.9479,  0.3333,  0.9757,  ..., -0.9532, -0.8662,  0.9854],
#          [-0.3927,  0.1298, -0.7258,  ...,  1.4342, -0.7562,  0.5968],
#          [-0.9479,  0.3333,  0.9757,  ..., -0.9532, -0.8662,  0.9854],
#          ...,
#          [-0.2584, -0.1067,  0.0065,  ...,  0.1718, -0.5527,  0.9756],
#          [-0.3927,  0.1298, -0.7258,  ...,  1.4342, -0.7562,  0.5968],
#          [-0.3927,  0.1298, -0.7258,  ...,  1.4342, -0.7562,  0.5968]],
#         grad_fn=<EmbeddingBackward>), tensor([[ 1.1524,  0.3584, -0.0950],
#          [ 1.1524,  0.3584, -0.0950],
#          [ 1.1524,  0.3584, -0.0950],
#          ...,
#          [ 1.1524,  0.3584, -0.0950],
#          [ 1.1524,  0.3584, -0.0950],
#          [ 1.1524,  0.3584, -0.0950]], grad_fn=<EmbeddingBackward>), tensor([[-1.5670],
#          [-1.5670],
#          [-1.5670],
#          ...,
#          [-1.5670],
#          [-1.5670],
#          [-1.5670]], grad_fn=<EmbeddingBackward>), tensor([[ 0.1528,  1.4775],
#          [ 0.1528,  1.4775],
#          [-0.2227, -0.1196],
#          ...,
#          [ 0.1528,  1.4775],
#          [ 0.1528,  1.4775],
#          [ 0.1528,  1.4775]], grad_fn=<EmbeddingBackward>)]

# %%
z = torch.cat(embedding_val, 1)
z
# Out:
# tensor([[-0.9479,  0.3333,  0.9757,  ..., -1.5670,  0.1528,  1.4775],
#         [-0.3927,  0.1298, -0.7258,  ..., -1.5670,  0.1528,  1.4775],
#         [-0.9479,  0.3333,  0.9757,  ..., -1.5670, -0.2227, -0.1196],
#         ...,
#         [-0.2584, -0.1067,  0.0065,  ..., -1.5670,  0.1528,  1.4775],
#         [-0.3927,  0.1298, -0.7258,  ..., -1.5670,  0.1528,  1.4775],
#         [-0.3927,  0.1298, -0.7258,  ..., -1.5670,  0.1528,  1.4775]],
#        grad_fn=<CatBackward>)

# %%
## implement dropout
dropout = nn.Dropout(.4)

# %%
final_embed = dropout(z)
final_embed
# Out:
# tensor([[-0.0000,  0.5556,  1.6262,  ..., -2.6117,  0.0000,  2.4625],
#         [-0.6545,  0.2163, -0.0000,  ..., -0.0000,  0.2547,  2.4625],
#         [-1.5799,  0.0000,  0.0000,  ..., -0.0000, -0.0000, -0.1994],
#         ...,
#         [-0.4306, -0.0000,  0.0109,  ..., -2.6117,  0.2547,  2.4625],
#         [-0.6545,  0.2163, -1.2097,  ..., -2.6117,  0.0000,  0.0000],
#         [-0.6545,  0.2163, -0.0000,  ..., -0.0000,  0.2547,  2.4625]],
#        grad_fn=<MulBackward0>)

# %%
### Create a Feed Forward Neural Network
import torch
import torch.nn as nn
import torch.nn.functional as F
class FeedForwardNN(nn.Module):

    def __init__(self, embedding_dim, n_cont, out_sz, layers, p=0.5):
        super().__init__()
        self.embeds = nn.ModuleList([nn.Embedding(inp,out) for inp,out in embedding_dim])
        self.emb_drop = nn.Dropout(p)
        self.bn_cont = nn.BatchNorm1d(n_cont)
        
        layerlist = []
        n_emb = sum((out for inp,out in embedding_dim))
        n_in = n_emb + n_cont
        
        for i in layers:
            layerlist.append(nn.Linear(n_in,i)) 
            layerlist.append(nn.ReLU(inplace=True))
            layerlist.append(nn.BatchNorm1d(i))
            layerlist.append(nn.Dropout(p))
            n_in = i
        layerlist.append(nn.Linear(layers[-1],out_sz))
            
        self.layers = nn.Sequential(*layerlist)
    
    def forward(self, x_cat, x_cont):
        embeddings = []
        for i,e in enumerate(self.embeds):
            embeddings.append(e(x_cat[:,i]))
        x = torch.cat(embeddings, 1)
        x = self.emb_drop(x)
        
        x_cont = self.bn_cont(x_cont)
        x = torch.cat([x, x_cont], 1)
        x = self.layers(x)
        return x

# %%
len(cont_features)
# Out:
# 5

# %%
torch.manual_seed(100)
model=FeedForwardNN(embedding_dim,len(cont_features),1,[100,50],p=0.4)

# %%
model
# Out:
# FeedForwardNN(
#   (embeds): ModuleList(
#     (0): Embedding(15, 8)
#     (1): Embedding(5, 3)
#     (2): Embedding(2, 1)
#     (3): Embedding(4, 2)
#   )
#   (emb_drop): Dropout(p=0.4, inplace=False)
#   (bn_cont): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=19, out_features=100, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=100, out_features=50, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.4, inplace=False)
#     (8): Linear(in_features=50, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Define loss and optimizer

# %%
loss_function=nn.MSELoss()
optimizer=torch.optim.Adam(model.parameters(),lr=0.01)

# %%
data.shape
# Out:
# (1201, 10)

# %%
cont_values
# Out:
# tensor([[   65.,  8450.,   856.,   854.,    17.],
#         [   80.,  9600.,  1262.,     0.,    44.],
#         [   68., 11250.,   920.,   866.,    19.],
#         ...,
#         [   66.,  9042.,  1188.,  1152.,    79.],
#         [   68.,  9717.,  1078.,     0.,    70.],
#         [   75.,  9937.,  1256.,     0.,    55.]])

# %%
cont_values.shape
# Out:
# torch.Size([1201, 5])

# %%
## train, test and split
batch_size=1200
test_size=int(batch_size*0.15)
train_categorical=cat_features[:batch_size-test_size]
test_categorical=cat_features[batch_size-test_size:batch_size]
train_cont=cont_values[:batch_size-test_size]
test_cont=cont_values[batch_size-test_size:batch_size]
y_train=y[:batch_size-test_size]
y_test=y[batch_size-test_size:batch_size]

# %%
len(train_categorical),len(test_categorical),len(train_cont),len(test_cont),len(y_train),len(y_test)
# Out:
# (1020, 180, 1020, 180, 1020, 180)

# %%
epochs=5000
final_losses=[]
for i in range(epochs):
    i=i+1
    y_pred=model(train_categorical,train_cont)
    loss=torch.sqrt(loss_function(y_pred,y_train)) ## RMSE
    final_losses.append(loss)
    if i%10==1:
        print("Epoch number: {} and the loss : {}".format(i,loss.item()))
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# Epoch number: 1 and the loss : 200496.78125
# Epoch number: 11 and the loss : 200493.4375
# Epoch number: 21 and the loss : 200489.15625
# Epoch number: 31 and the loss : 200482.609375
# Epoch number: 41 and the loss : 200473.265625
# Epoch number: 51 and the loss : 200461.359375
# Epoch number: 61 and the loss : 200446.390625
# Epoch number: 71 and the loss : 200429.359375
# Epoch number: 81 and the loss : 200408.0
# Epoch number: 91 and the loss : 200383.421875
# Epoch number: 101 and the loss : 200355.3125
# Epoch number: 111 and the loss : 200322.125
# Epoch number: 121 and the loss : 200291.40625
# Epoch number: 131 and the loss : 200252.0
# Epoch number: 141 and the loss : 200206.609375
# Epoch number: 151 and the loss : 200162.234375
# Epoch number: 161 and the loss : 200112.234375
# Epoch number: 171 and the loss : 200059.65625
# Epoch number: 181 and the loss : 200005.875
# Epoch number: 191 and the loss : 199946.40625
# Epoch number: 201 and the loss : 199881.59375
# Epoch number: 211 and the loss : 199816.09375
# Epoch number: 221 and the loss : 199737.296875
# Epoch number: 231 and the loss : 199670.84375
# Epoch number: 241 and the loss : 199589.34375
# Epoch number: 251 and the loss : 199507.84375
# Epoch number: 261 and the loss : 199411.109375
# Epoch number: 271 and the loss : 199324.609375
# Epoch number: 281 and the loss : 199245.890625
# Epoch number: 291 and the loss : 199140.796875
# Epoch number: 301 and the loss : 199029.890625
# Epoch number: 311 and the loss : 198935.015625
# Epoch number: 321 and the loss : 198847.703125
# Epoch number: 331 and the loss : 198696.453125
# Epoch number: 341 and the loss : 198604.015625
# Epoch number: 351 and the loss : 198490.84375
# Epoch number: 361 and the loss : 198389.984375
# Epoch number: 371 and the loss : 198248.765625
# Epoch number: 381 and the loss : 198104.734375
# Epoch number: 391 and the loss : 198018.671875
# Epoch number: 401 and the loss : 197893.453125
# Epoch number: 411 and the loss : 197726.015625
# Epoch number: 421 and the loss : 197596.953125
# Epoch number: 431 and the loss : 197423.53125
# Epoch number: 441 and the loss : 197285.734375
# Epoch number: 4931 and the loss : 35817.66796875
# Epoch number: 4941 and the loss : 36405.8046875
# Epoch number: 4951 and the loss : 34131.24609375
# Epoch number: 4961 and the loss : 34519.375
# Epoch number: 4971 and the loss : 35883.7421875
# Epoch number: 4981 and the loss : 35455.96875
# Epoch number: 4991 and the loss : 32694.431640625

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline
plt.plot(range(epochs), final_losses)
plt.ylabel("RMSE Loss")
plt.xlabel("Epoch")
# Out:
# Text(0.5, 0, 'Epoch')

# %%
### Validate the Test Data
y_pred=""
with torch.no_grad():
    y_pred=model(test_categorical,test_cont)
    loss=torch.sqrt(loss_function(y_pred,y_test))
print('RMSE: {}'.format(loss))
# Out:
# RMSE: 57231.2265625

# %%
data_verify=pd.DataFrame(y_test.tolist(),columns=["Test"])

# %%
data_predicted=pd.DataFrame(y_pred.tolist(),columns=["Prediction"])

# %%
data_predicted
# Out:
#         Prediction
# 0    142821.593750
# 1    215776.000000
# 2    145253.312500
# 3    206202.250000
# 4    217923.750000
# 5    202410.437500
# 6    145363.343750
# 7    292218.937500
# 8    150224.906250
# 9    373856.812500
# 10   211731.953125
# 11   204247.031250
# 12   188749.796875
# 13   111248.828125
# 14   180358.000000
# 15   116212.476562
# 16   245388.312500
# 17   131720.625000
# 18   296472.812500
# 19    67841.750000
# 20   187830.218750
# 21   116565.304688
# 22   100509.523438
# 23   197735.468750
# 24   208224.062500
# 25   189706.906250
# 26   146894.656250
# 27   349572.562500
# 28   160872.843750
# 29   158780.468750
# 30    76312.867188
# 31   127409.546875
# 32   273617.625000
# 33    62523.539062
# 34   228544.718750
# 35   198249.343750
# 36   130592.179688
# 37   136977.906250
# 38   148405.531250
# 39   103587.539062
# 40   244080.656250
# 41   303564.468750
# 42    84155.210938
# 43   159520.718750
# 44   195088.468750
# 45    99555.421875
# 46   107756.531250
# 47   142193.500000
# 48   146177.937500
# 49   719420.000000
# 50   128396.898438
# 51   347846.156250
# 52   209932.703125
# 53   145198.343750
# 54   242931.500000
# 55   182688.484375
# 56   133489.500000
# 57   123191.914062
# 58   275171.093750
# 59   182434.062500
# 60   321548.093750
# 61   106537.710938
# 62   223434.250000
# 63   225592.968750
# 64   159017.218750
# 65   127334.843750
# 66   166117.375000
# 67   255805.062500
# 68    74953.773438
# 69   244045.578125
# 70    92493.070312
# 71    71381.054688
# 72    96836.304688
# 73   263095.718750
# 74   201771.406250
# 75   215582.250000
# 76   142886.906250
# 77    97587.531250
# 78   124741.117188
# 79   112980.406250
# 80   143730.375000
# 81   134841.953125
# 82    64163.601562
# 83   259266.796875
# 84   115802.367188
# 85   103693.601562
# 86   156854.781250
# 87   132380.046875
# 88   146493.562500
# 89   117391.882812
# 90   281676.156250
# 91   126678.875000
# 92   178597.312500
# 93   132597.984375
# 94   128446.843750
# 95   358734.062500
# 96   207445.437500
# 97   366733.468750
# 98   248875.062500
# 99   246589.921875
# 100  167279.921875
# 101  175070.312500
# 102  213773.000000
# 103  113479.031250
# 104  216443.218750
# 105  150127.187500
# 106  160689.968750
# 107  245582.953125
# 108  268181.000000
# 109  235160.625000
# 110  102148.023438
# 111  129197.164062
# 112   48933.000000
# 113  195063.937500
# 114  120428.656250
# 115  156646.031250
# 116  124995.820312
# 117  125725.796875
# 118  363581.468750
# 119  313875.906250
# 120  215877.656250
# 121  109616.414062
# 122  173215.031250
# 123  122636.726562
# 124   95297.062500
# 125  132327.921875
# 126  208544.562500
# 127  303461.031250
# 128  101790.250000
# 129  159590.203125
# 130  105250.945312
# 131  118640.070312
# 132  200014.296875
# 133  174644.218750
# 134  237890.515625
# 135  114009.281250
# 136  200823.812500
# 137  141479.062500
# 138  147977.843750
# 139  231933.656250
# 140  229836.343750
# 141  162935.687500
# 142   82760.039062
# 143  296991.031250
# 144  147187.609375
# 145  242656.343750
# 146  139303.968750
# 147  137583.468750
# 148  143458.218750
# 149  130634.398438
# 150  125861.468750
# 151  136062.156250
# 152  193254.000000
# 153  136430.843750
# 154  101501.476562
# 155  209705.156250
# 156  105764.070312
# 157  192197.187500
# 158  159662.031250
# 159  170752.437500
# 160  123974.117188
# 161  325319.656250
# 162  130623.906250
# 163  183240.500000
# 164  194296.578125
# 165  360600.625000
# 166  200226.906250
# 167  102525.953125
# 168  266735.968750
# 169  112973.085938
# 170   90142.875000
# 171  111706.640625
# 172  288531.062500
# 173   95877.414062
# 174  160562.500000
# 175  179504.515625
# 176  168005.312500
# 177  246048.750000
# 178  230876.593750
# 179  125588.585938

# %%
final_output=pd.concat([data_verify,data_predicted],axis=1)
final_output['Difference']=final_output['Test']-final_output['Prediction']
final_output.head()
# Out:
#        Test    Prediction   Difference
# 0  130000.0  142821.59375 -12821.59375
# 1  138887.0  215776.00000 -76889.00000
# 2  175500.0  145253.31250  30246.68750
# 3  195000.0  206202.25000 -11202.25000
# 4  142500.0  217923.75000 -75423.75000

# %%
## save the model
torch.save(model,'HousePrice.pt')

# %%
torch.save(model.state_dict(), "HouseWeights.pt")

# %%
## load the save model
embs_size=[(15, 8), (5, 3), (2, 1), (4, 2)]
model1=FeedForwardNN(embs_size,5,1,[100,50],p=0.4)

# %%
model1.load_state_dict(torch.load('HouseWeights.pt'))
# Out:
# <All keys matched successfully>

# %%
model1.eval()
# Out:
# FeedForwardNN(
#   (embeds): ModuleList(
#     (0): Embedding(15, 8)
#     (1): Embedding(5, 3)
#     (2): Embedding(2, 1)
#     (3): Embedding(4, 2)
#   )
#   (emb_drop): Dropout(p=0.4, inplace=False)
#   (bn_cont): BatchNorm1d(5, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layers): Sequential(
#     (0): Linear(in_features=19, out_features=100, bias=True)
#     (1): ReLU(inplace=True)
#     (2): BatchNorm1d(100, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.4, inplace=False)
#     (4): Linear(in_features=100, out_features=50, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.4, inplace=False)
#     (8): Linear(in_features=50, out_features=1, bias=True)
#   )
# )
